# %% [markdown]
# # Stima del costo token-per-token
# Scrivi breve programma per calcolare prezzo per token di un input di un modello selezionato.
#
# Pianifica brevemente la soluzione.
#
# Info ufficiali e prezzi aggiornati:
# openai.com/api/pricing/
#
# Per il calcolo del numero dei token usa la libreria tiktoken.
#
# Verificare numero dei token:
# https://platform.openai.com/tokenizer
#
# Usa GitHub pull request per consegnare il programma.

# %%
import tiktoken

def calcola_prezzo_per_token(input_text, modello, prezzo_per_1000_token):
    # Inizializza il codificatore per il modello selezionato
    codificatore = tiktoken.encoding_for_model(modello)
    
    # Calcola il numero di token
    numero_token = len(codificatore.encode(input_text))
    
    # Calcola il prezzo per token
    prezzo_per_token = prezzo_per_M_token / 1e6
    costo_totale = numero_token * prezzo_per_token
    
    return numero_token, costo_totale

# Esempio con testo da 11 tokens (confirmed by https://platform.openai.com/tokenizer)
# input_text = "Sopra la panca la capra canta ..."

# Esempio con testo da > 2000 tokens
input_text = """Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio.
Lorem ipsum dolor sit amet.
Aut aspernatur quia sed error porro aut dolorem facilis qui dolores illum eum magni aspernatur qui error quaerat ut eveniet dolore.
Quo suscipit quia est quas minus ab iusto voluptatem eum sint quos quo voluptatum incidunt.
Ad sapiente voluptas et beatae quas nam amet atque.
Non consequuntur ipsa ea laudantium earum aut optio repellat est iusto galisum!
Nam natus possimus in exercitationem autem a voluptatibus aspernatur et ducimus atque.
Et quidem ratione eum totam expedita sit cumque voluptatum et facere quaerat aut odio tempora.
Et tenetur Quis et provident ullam et tempore voluptatum.
Qui voluptate quae ut corrupti odio et quisquam blanditiis cum similique magnam eum modi aperiam aut internos odit ea sequi odio."""

# Seleziona modello
modello = "gpt-4o" 

if modello == "gpt-4o":
    prezzo_per_M_token = 5
elif modello == "o4-mini":
    prezzo_per_M_token = 1100
elif modello == "gpt-4.1-mini":
    prezzo_per_M_token = 0.4
else:
    raise ValueError("Modello non supportato")

numero_token, costo_totale = calcola_prezzo_per_token(input_text, modello, prezzo_per_M_token)
print(f"Numero di token: {numero_token}, Costo totale: {costo_totale:.4f}€")
# Out:
# Numero di token: 2028, Costo totale: 0.0101€
